# %% [markdown]
# # To do:
# 1. Aggiungere date esami mancanti
# 2. Metodi, poi As
#
#
# # Organizzazione studio materie mancanti
# 1. **metodi**:
# <br>
# &emsp;    finire studio + schemi già iniziato.
# <br>
# &emsp;    quantificare: ...
# 2. **as**:
# <br>
# &emsp;    importantissimo: scrivere fne esplicitamente da link notebook FIt_covid con referenza (subito dopo metodi)
# <br>
# &emsp;    simulazioni: vedere limite iterazioni
# <br>
# &emsp;    finire studiare lezioni
# <br>
# &emsp;    finire presentazione: semplificare + roba teoria ML, intervallo date (linee verticali) con t0,  tq, tX0, markovianità, discorso inglese, eq Gibbs, video inferenza Bayes, likelihood ed errore (provare a scrivere con numba tutto l'algoritmo)
# <br>
# &emsp;    quantificare: ...
# 3. **dda**:
# <br>
# &emsp;    finire report 3
# <br>
# &emsp;    sistemare fit multivariato gauss
# <br>
# &emsp;    relazione 1, 2, 3
# <br>
# &emsp;    presentazione su articolo
# <br>
# &emsp;    studio teoria
# 4. **metodi probabilistici**:
# <br>
# &emsp;    riscrivere a monte e lavorare alla tesina per dopo settembre
# <br>
# &emsp;    implemetare moltiplicatori di lagrange
# 5. **ML**:
# <br>
# 6. **MQ2**:
# <br>

# %%
import pandas as pd
import numpy as np

# %%
# Add exame's dates dictonary
dic = {
    'as': ['14/09/2021'],
    'dda': ['14/09/2021'],
    'ML': [pd.NaT],
    'MB': [pd.NaT],
    'MQ': ['14/09/2021'],
}

# Add cfu dictonary
cfus = {
    'MQ': 8.,
    'as': 10.,
    'dda': 8.,
    'cp': 8.,    # chiedere Pecchia se possibile da 6 cfu
    'ML': 9.,
    'MB': 6.
}

df = pd.DataFrame(dic).T
for ind in df.index:
    df.loc[ind, :] = pd.to_datetime(df.loc[ind, :], format='%d/%m/%Y')

df.T
# Out:
#       metodi         as        dda  ML  MB         MQ
# 0 2021-09-16 2021-09-14 2021-09-14 NaT NaT 2021-09-14

# %%
def days_hours_minutes(td):
    string = f'{td.days}d {td.seconds//3600}h {(td.seconds//60)%60}m'
    return string


df1 = df.copy()
m = len(df1.columns)

for i in range(m):
    for j, subject in enumerate(df1.index):
        delta = df.loc[subject, i] - pd.Timestamp.today()
        df1.iloc[j, i] = days_hours_minutes(delta)

df1 = df1.replace('nand, nanh, nanm', 'nan')
df1['cfu'] = df1.index.map(cfus)
df1.loc['cp', 'cfu'] = '6/8'

df1.loc[df1.index.isin(['metodi', 'as', 'dda'])].T
# Out:
#          metodi         as        dda
# 0    11d 3h 40m  9d 3h 40m  9d 3h 40m
# cfu           8         10          8

# %% [markdown]
# # Metodi

# %%
"""
Finito un argomento cancellarlo dalla lista corrispondente.
"""
import random

# Functions of a complex variable: 1.1 -> 1.6
#Theory of analytic functions: Complements
List1 = ["Basic properties of holomorphic functions", "classification of singularities",
        "Complex Integrals", "Cauchy’s theorem", "Calculus of Residues", "Jordan’s Lemma",
        "Residue Theorem", "Cauchy’s Integral Formula", "Taylor and Laurent expansions",
        "Theorem of the maximum modulus", "analytic continuation", "multi-valued functions",
        "Riemann surfaces", "Riemann sphere and point at infinity",
        "Pole expansion of meromorphic functions", "Mittag-Leffler’s expansions",
        "Sommerfeld-Watson transformation", "Sum of series", "Logarithmic derivative",
        "Principle of the argument and winding number", "Rouche’s Theorem",
        "Infinite products representation of a complex function and Convergence properties",
        "Weierstrass product expansion", "Wallis formula", "Theorem of Local invertibility of analytic functions",
        "Lagrange’s formula", "Reciprocal of an analytic function: the Cauchy’s Product Method"]

# Asymptotic expansions: 2.1 -> 2.7
List2 = ["Asymptotic expansions: Definition, properties and applications", "Integration by parts",
        "Laplace Integrals", "Laplace Method", "Watson Lemma","Stirling’s Formula",
        "Stokes Phenomenon and analytic continuation", "Stationary Phase Method","Saddle Point Method"]

# Ordinary Differential Equations: 3.1.1 -> 3.1.15
List3_1 =["Cauchy Problems", "Cauchy and Peano’s Theorems", "Non-linear equations and spontaneous singularities",
        "Linear differential equations of the second order", "Boundary Value Problems", "Sturm-Liouville problems",
        "Homogeneous equations: Equations with constant coefficients", "Euler equation", "Wronskian method",
        "Homogeneous equations: applications and examples", "Inhomogeneous equations: Method of the Green Function",
        "Green Function: Applications and physical motivation", "Elements of Theory of Distributions",
        "Regular and singular distributions", "Temperate distributions", "Operations on distributions",
        "Derivatives of distributions", "Green’s Theorem",
        "Green Functions with zero modes: the Fredholdm Alternative Theorem and the Modified Green Function",
        "Modified Green Function: Applications and examples", "ODE in complex space Power Series Methods",
        "Solutions about ordinary points", "Hermite equation and Hermite Polynomials",
        "Solutions about regular singular (or Fuchsian) points","Euler’s Equation", "Study of the point at infinity",
        "Frobenius Series Method", "Equations with one and two regular singular points", 
        "1 or 2 regular singular point applications",
        "Equations with three regular singular points (Papperitz-Riemann), with applications", 
        "Riemann P-symbol and its properties", "Hypergeometric Equation","Associated Legendre Equation", 
        "Confluent Hypergeometric Equation","Bessel Equation"]

# Partial Differential Equations: 3.2.1 -> 3.2.5
List3_2 = ["PDE example: Laplace’s equation, Poisson’s Equation, Wave equation, Helmholtz’s equation",
            "Separation of variables method", "Helmholtz equation: solution in spherical polar coordinates",
            "Spherical Harmonic Decomposition", "Radial solution of central force problems",
            "Solutions with Fourier Transforms", "Elements of Fourier Analysis", "Fourier Series and convergence",
            "Fourier transform and its inverse", "Properties of the transform", "Fourier transform of distributions",
            "Fourier transform Applications and examples"]

# Special Functions of physical science
List4 = ["Gamma function", "Diagamma function", "Beta function", "Zeta function", "Hypergeometric function",
        "Confluent hypergeometric functions", "Hermite Polynomials", "Laguerre Polynomials",
        "Legendre functions and associated Legendre functions", "Legendre Polynomials",
        "Orthogonality relation (legendre polynomials)", "Rodrigues Formula for orthogonal polynomials",
        "Spherical Harmonics", "Bessel functions", "Modified and spherical Bessel functions"]

Lists = [List1, List2, List3_1, List3_2, List4]

Capitoli = ["Functions of a complex variable: Theory of analytic functions: Complements",
            "Asymptotic expansions", "Ordinary Differential Equations", "Partial Differential Equations",
            "Special Functions of physical science"]


def Random_arg(lists):
    arg = random.choice(lists)
    i = Lists.index(lists)
    print(f'\033[1mChapter:\033[0m\n{Capitoli[i]}')

    if i in [2, 3]:
        print(f"\033[1mList extracted:\033[0m\n List 3.{i - 1}")
        print(f"\033[1mSection argument number:\033[0m\n 3.{i - 1}.{lists.index(arg) + 1}")
    else:
        if i == 4:
            i -= 1
        print(f"List{i + 1}")
        print(f"\033[1mSection argument number:\033[0m\n{i + 1}.{lists.index(arg) + 1}")
    print(f'\033[1mArgument:\033[0m\n{arg}')


lista = random.choice(Lists)
Random_arg(lista)
# Out:
# Chapter:
# Ordinary Differential Equations
# List extracted:
#  List 3.1
# Section argument number:
#  3.1.11
# Argument:
# Inhomogeneous equations: Method of the Green Function

# %%
print('\033[1m Text \033[0m')
# Out:
#  Text

# %%
def remaining_args(nargs_done):
    rem_args = pd.Series(prog['Sect1'][~prog['Sect1'].isin([None])], dtype='object')
    for sect in prog.columns[1:]:
        rem_args = rem_args.append(prog[sect][~prog[sect].isin([None])], ignore_index=True)
    return rem_args[nargs_done:]

# %%
prog = pd.DataFrame(Lists, index=['Sect1', 'Sect2', 'Sect3.1', 'Sect3.2', 'Sect4']).T


prog
# Out:
#                                                 Sect1  \
# 0           Basic properties of holomorphic functions
# 1                     classification of singularities
# 2                                   Complex Integrals
# 3                                    Cauchy’s theorem
# 4                                Calculus of Residues
# 5                                      Jordan’s Lemma
# 6                                     Residue Theorem
# 7                           Cauchy’s Integral Formula
# 8                       Taylor and Laurent expansions
# 9                      Theorem of the maximum modulus
# 10                              analytic continuation
# 11                             multi-valued functions
# 12                                   Riemann surfaces
# 13               Riemann sphere and point at infinity
# 14            Pole expansion of meromorphic functions
# 15                        Mittag-Leffler’s expansions
# ...

# %%
args_done = len(prog['Sect1'][~prog['Sect1'].isin([None])]) + \
            len(prog['Sect2'][~prog['Sect2'].isin([None])]) + \
            prog['Sect3.1'][prog['Sect3.1'] == 'Modified Green Function: Applications and examples'].index[0] + 1 + \
            0 + \
            0
days_left = float(df1.loc['metodi', 0].split(' ')[0][:-1])


tot_arg = 0.
for column in prog.columns:
    print(column, len(prog.loc[~prog[column].isna(), column]))
    tot_arg += len(prog.loc[~prog[column].isna(), column])

print('\n')
print(f'{(tot_arg - args_done) / (days_left - 1)} al giorno, con un giorno libero (giorno prima esame)')
print(f'svolto il {args_done / tot_arg * 100:.1f} % del programma')
print('Argomenti da fare:')
remaining_args(args_done)
# Out:
# Sect1 27
# Sect2 9
# Sect3.1 35
# Sect3.2 12
# Sect4 15
#
#
# 4.2 al giorno, con un giorno libero (giorno prima esame)
# svolto il 57.1 % del programma
# Argomenti da fare:
# 56            ODE in complex space Power Series Methods
# 57                      Solutions about ordinary points
# 58             Hermite equation and Hermite Polynomials
# 59    Solutions about regular singular (or Fuchsian)...
# 60                                     Euler’s Equation
# 61                       Study of the point at infinity
# 62                              Frobenius Series Method
# 63    Equations with one and two regular singular po...
# 64           1 or 2 regular singular point applications
# 65    Equations with three regular singular points (...
# 66                  Riemann P-symbol and its properties
# 67                              Hypergeometric Equation
# 68                         Associated Legendre Equation
# 69                    Confluent Hypergeometric Equation
# ...

# %%
# Schedule

ind = pd.date_range("8:00", "23:00", freq="1H").strftime('%H:%M')
indices = ind[:] + '-' + ind[1:].append(pd.Index(['00:00']))
days = pd.date_range("21/06/2021", "27/06/2021", freq="1d").strftime('%A')

tmp = pd.DataFrame(columns=days, index=indices)
tmp.loc['08:00-09:00', : ] = 'breakfast'
tmp.loc['13:00-14:00', : ] = 'lunch'
tmp.loc['20:00-21:00', : ] = 'dinner'
tmp.loc['20:00-21:00', ['Tuesday', 'Wednesday']] = np.nan
tmp.loc['18:00-19:00', ['Tuesday', 'Wednesday']] = 'dinner'

# weekly hours for studying
week = np.unique(tmp.loc[:'18:00-19:00', :].isna(), return_counts=True)[1][1]


tmp
# Out:
#                 Monday    Tuesday  Wednesday   Thursday     Friday   Saturday  \
# 08:00-09:00  breakfast  breakfast  breakfast  breakfast  breakfast  breakfast
# 09:00-10:00        NaN        NaN        NaN        NaN        NaN        NaN
# 10:00-11:00        NaN        NaN        NaN        NaN        NaN        NaN
# 11:00-12:00        NaN        NaN        NaN        NaN        NaN        NaN
# 12:00-13:00        NaN        NaN        NaN        NaN        NaN        NaN
# 13:00-14:00      lunch      lunch      lunch      lunch      lunch      lunch
# 14:00-15:00        NaN        NaN        NaN        NaN        NaN        NaN
# 15:00-16:00        NaN        NaN        NaN        NaN        NaN        NaN
# 16:00-17:00        NaN        NaN        NaN        NaN        NaN        NaN
# 17:00-18:00        NaN        NaN        NaN        NaN        NaN        NaN
# 18:00-19:00        NaN     dinner     dinner        NaN        NaN        NaN
# ...
